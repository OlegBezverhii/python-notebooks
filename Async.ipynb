# %% [markdown]
# import asyncio

# %% [markdown]
# async def main():
#     print(1)
#
# await main()

# %% [raw]
# # https://stackoverflow.com/questions/55409641/asyncio-run-cannot-be-called-from-a-running-event-loop
# async def main():
#     print('Hello ...')
#     await asyncio.sleep(1)
#     print('... World!')
# asyncio.run(main())

# %% [raw]
# # https://overcoder.net/q/2714561/завершить-работу-скрипта-python-через-x-секунд-бездействия

# %% [markdown]
# ## Пример работы Watchdog

# %%
from sound import Sound

volum_half=50  # 50% громкость
volum_full=100 # 100% громкость

# %%
import os
import signal
import threading

#объявим класс Watchdog - он будет следить за истечением таймера
class Watchdog():
    
    #инициализация класса
    def __init__(self, timeout=30):
        #Передаем значение таймаута (по умолчанию 30)
        self.timeout = timeout
        #Переменная таймера потока
        self._t = None

    #выполнить функцию (не обязательно, можно выполнить сразу в _expire)
    def do_expire(self):
        #Выполняем функцию
        Sound.volume_set(volum_half)
        print("Watchdog do_expire")

    #Функция окончания времени таймера и что пора выполнить действие
    #в моем случае уменьшить звук
    def _expire(self):
        print("Watchdog expire")
        #Вызываем нашу функцию
        self.do_expire()

    #
    def start(self):
        #Если переменная не инициализированная
        if self._t is None:
            #Делаем звук 100%
            Sound.volume_max()
            #Задаем таймер
            self._t = threading.Timer(self.timeout, self._expire)
            #Стартуем таймер
            self._t.start()
            print("Watchdog start")

    #
    def stop(self):
        #Если переменная инициализированна
        if self._t is not None:
            #Завершаем наш таймер
            self._t.cancel()
            #Переменная становится не инициализированной
            self._t = None
            #print("\nWatchdog stop")

    #рестарт Watchdog
    def refresh(self):
        #Если переменная инициализированна
        if self._t is not None:
            print("Watchdog refresh function")
            self.stop()
            self.start()

# %% [markdown]
# Sound.volume_up() # увеличим громкость на 2 единицы
# current = Sound.current_volume() # текущая громкость, если кому-то нужно
#
# Sound.volume_max() # выставляем сразу по максимуму

# %%
watchdog = Watchdog(timeout=10)

# %%
from pynput import mouse

def on_move(x, y):
    print('Pointer moved to {0}'.format((x, y)))
    print("Watchdog refresh")
    watchdog.refresh()
    
def on_click(x, y, button, pressed):
    #print('{0} at {1}'.format('Pressed' if pressed else 'Released',(x, y)))
    #  Get the reply.
    print("Watchdog refresh")
    watchdog.refresh()
    if not pressed:
        # Stop listener
        watchdog.stop()
        return False

def on_scroll(x, y, dx, dy):
    print('Scrolled {0} at {1}'.format('down' if dy < 0 else 'up',(x, y)))
    watchdog.refresh()

# %%
watchdog.start()

with mouse.Listener(
        on_move=on_move,
        on_click=on_click,
        on_scroll=on_scroll) as listener:
    listener.join()
# Out:
# Watchdog start
# Pointer moved to (689, 168)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (690, 168)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (691, 168)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (692, 169)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (693, 169)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (694, 170)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (695, 171)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (697, 172)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (698, 173)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (698, 174)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (699, 175)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (700, 176)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (700, 177)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (701, 178)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (702, 179)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (702, 181)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (702, 182)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (703, 183)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (704, 185)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (704, 187)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (705, 189)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (706, 192)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (706, 194)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (707, 196)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (708, 199)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (709, 202)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (710, 205)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (711, 209)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (712, 212)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (713, 216)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (714, 219)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (715, 222)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (716, 227)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (716, 231)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (718, 236)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (719, 240)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (720, 243)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (722, 247)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (723, 251)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (724, 255)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (726, 259)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (726, 262)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (728, 266)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (730, 269)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (731, 273)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (733, 276)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (734, 280)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (735, 282)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (737, 285)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (737, 288)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (739, 290)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (739, 292)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (740, 295)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (741, 297)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (741, 299)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (741, 300)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 302)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 304)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 305)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 307)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 309)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 310)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 311)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 313)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 314)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 315)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 317)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 319)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 320)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 321)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (741, 321)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (741, 323)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (740, 324)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (740, 325)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Watchdog expire
# Watchdog do_expire
# Pointer moved to (740, 322)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 296)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (743, 292)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (744, 286)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (745, 283)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (745, 279)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (745, 276)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (746, 274)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (746, 271)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 268)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 265)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 263)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 261)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 258)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 255)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 252)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 250)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (747, 246)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (746, 244)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (745, 241)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (744, 238)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (743, 236)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 232)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (740, 230)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (740, 228)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (738, 224)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (736, 221)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (735, 219)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (734, 217)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (731, 213)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (730, 211)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (729, 209)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (727, 207)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (725, 205)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (724, 203)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (722, 201)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (721, 200)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (719, 199)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (718, 197)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (716, 197)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (715, 195)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (713, 194)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (712, 193)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (710, 192)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (709, 192)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (707, 191)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (705, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (703, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (701, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (700, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (698, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (696, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (694, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (693, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (692, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (690, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (688, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (687, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (685, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (684, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (683, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (681, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (680, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (678, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (677, 190)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (676, 191)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (674, 192)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (673, 192)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (672, 193)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (671, 194)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (670, 194)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (669, 194)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (668, 196)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (666, 196)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (665, 198)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 199)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 200)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 200)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 201)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 202)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 203)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 204)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 205)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 206)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (662, 207)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (662, 208)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 209)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 210)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 211)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 212)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 214)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 216)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 217)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 218)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 219)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 220)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 221)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 222)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 223)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 225)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 226)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 227)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 229)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 230)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 231)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (662, 231)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (662, 233)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (662, 234)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (662, 235)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 236)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 237)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 238)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 239)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 240)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 241)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 242)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 243)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 244)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 245)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 246)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 247)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 248)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 249)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 251)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 252)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 253)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 255)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 256)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 258)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 260)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 262)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 263)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 265)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 267)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 269)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 271)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 273)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 275)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (663, 277)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (662, 280)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 282)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 284)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (660, 286)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (659, 288)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (658, 291)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (657, 293)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (656, 295)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (655, 297)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (654, 299)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (652, 302)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (651, 304)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (650, 306)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (649, 308)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (647, 310)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (646, 313)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (645, 315)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (643, 317)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (641, 319)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (640, 321)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (639, 321)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (637, 324)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (636, 326)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (635, 328)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (632, 330)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (631, 332)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 333)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (628, 336)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (626, 338)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (624, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (622, 341)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (620, 343)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (618, 346)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (616, 348)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (614, 350)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (612, 352)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (610, 354)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (608, 356)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (606, 359)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (604, 361)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (601, 363)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (598, 365)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (596, 367)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (594, 370)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (591, 372)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (589, 374)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (586, 377)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (584, 379)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (581, 381)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (579, 383)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (575, 387)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (573, 389)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (571, 392)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (567, 394)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (564, 396)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (561, 398)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (558, 401)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (555, 403)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (552, 406)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (548, 408)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (545, 410)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (542, 412)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (538, 415)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (535, 417)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (531, 418)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (528, 421)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (525, 423)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (521, 425)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (518, 427)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (515, 428)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (511, 430)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (509, 431)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (505, 433)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (503, 434)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (499, 435)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (496, 437)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (494, 438)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (491, 438)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (488, 439)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (486, 440)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (484, 441)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (482, 441)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (480, 442)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (478, 442)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (476, 443)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (474, 443)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (473, 443)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (472, 444)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (470, 444)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (469, 445)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (467, 445)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (465, 445)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Watchdog expire
# Watchdog do_expire
# Pointer moved to (467, 445)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (477, 439)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (481, 436)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (484, 434)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (487, 432)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (489, 431)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (493, 428)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (500, 423)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (504, 421)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (508, 419)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (513, 416)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (528, 407)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (533, 405)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (538, 401)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (544, 399)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (550, 395)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (555, 393)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (561, 389)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (567, 386)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (573, 383)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (580, 380)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (586, 377)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (592, 374)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (599, 371)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (605, 368)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (612, 365)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (618, 362)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (624, 360)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (630, 357)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (636, 354)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (642, 352)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (648, 349)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (655, 347)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (660, 345)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (667, 343)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (671, 341)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (677, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (682, 337)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (687, 335)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (691, 334)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (696, 333)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (700, 331)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (705, 330)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (709, 329)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (713, 327)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (717, 327)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (720, 325)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (723, 324)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (726, 323)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (728, 322)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (731, 322)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (733, 320)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (735, 320)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (738, 320)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (739, 320)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (741, 319)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (743, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (744, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (745, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (746, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Watchdog expire
# Watchdog do_expire
# Pointer moved to (745, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (742, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (741, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (740, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (738, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (737, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (736, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (734, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (731, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (730, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (729, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (725, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (721, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (720, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (716, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (714, 318)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (709, 319)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (706, 319)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (703, 319)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (701, 320)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (698, 321)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (696, 321)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (692, 321)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (689, 322)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (686, 323)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (682, 324)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (679, 324)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (676, 324)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (672, 326)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (668, 326)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (664, 327)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (661, 328)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (657, 328)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (653, 329)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (649, 330)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (646, 330)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (641, 331)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (638, 332)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (634, 332)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (630, 333)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (626, 334)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (621, 335)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (617, 336)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (613, 336)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (609, 336)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (605, 337)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (601, 337)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (597, 338)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (593, 338)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (589, 338)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (585, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (581, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (577, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (573, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (569, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (565, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (562, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (558, 339)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (554, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (551, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (548, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (544, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (541, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (538, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (534, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (531, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (529, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (525, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (523, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (521, 340)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (519, 341)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (517, 341)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (516, 341)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (514, 341)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (513, 342)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (512, 342)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (511, 342)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (510, 343)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (509, 343)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Watchdog expire
# Watchdog do_expire
# Pointer moved to (509, 344)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (513, 346)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (516, 347)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (517, 348)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (518, 348)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (521, 349)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (522, 350)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (524, 350)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (525, 351)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (528, 352)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (530, 353)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (531, 354)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (533, 354)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (535, 355)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (536, 356)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (537, 357)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (540, 358)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (542, 359)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (543, 359)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (545, 359)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (546, 361)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (547, 361)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (549, 361)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (550, 362)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (551, 363)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (553, 363)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (554, 363)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (555, 363)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (559, 365)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (560, 365)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (561, 365)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (562, 365)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (563, 365)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (563, 366)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (564, 366)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (565, 367)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (566, 367)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (566, 368)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (566, 369)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (566, 370)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (566, 371)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (567, 372)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (568, 373)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (568, 374)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (568, 376)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (568, 377)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (568, 378)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (570, 379)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (570, 381)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (570, 383)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (572, 385)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (572, 387)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (573, 388)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (574, 390)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (575, 392)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (576, 394)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (577, 396)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (578, 398)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (579, 401)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (580, 403)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (582, 406)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (583, 408)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (584, 410)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (586, 414)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (587, 416)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (588, 418)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (590, 420)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (590, 424)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (592, 427)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (594, 429)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (594, 432)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (596, 435)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (598, 438)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (599, 441)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (601, 444)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (601, 447)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (603, 449)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (604, 453)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (605, 456)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (607, 459)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (607, 462)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (609, 465)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (610, 469)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (611, 472)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (612, 475)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (613, 479)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (615, 482)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (615, 486)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (617, 489)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (618, 493)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (619, 496)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (620, 500)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (621, 503)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (621, 506)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (623, 509)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (623, 513)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (625, 515)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (625, 519)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (625, 522)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (627, 526)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (627, 528)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (627, 530)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (628, 533)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (628, 536)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 538)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 540)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 541)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 544)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 545)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 547)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 548)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 549)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 550)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (629, 551)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (630, 552)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Pointer moved to (630, 553)
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Watchdog refresh
# Watchdog refresh function
# Watchdog start
# Watchdog refresh
# Watchdog refresh function
# Watchdog start

# %%
# ... здесь программа что-то делает
# и перезапускает отсчёт при любой активности пользователя
watchdog.refresh()

# в конце отменяем вызов func совсем или просто из программы выходим
watchdog.cancel()

# %%
# ...or, in a non-blocking fashion:
listener = mouse.Listener(
    on_move=on_move,
    on_click=on_click,
    on_scroll=on_scroll)
listener.start()
