# %%
import numpy as np
import pandas as pd

# %%
jornal = pd.read_csv('aspt3_msgs.csv', delimiter=';', low_memory=False)

# %%
jornal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881968 entries, 0 to 881967
# Data columns (total 13 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ID        881968 non-null  int64
#  1   IDMESS    881968 non-null  int64
#  2   USERNAME  881968 non-null  object
#  3   PLACE     881968 non-null  object
#  4   DTIME     881968 non-null  object
#  5   DTIMEACK  312247 non-null  object
#  6   SYSID     881968 non-null  int64
#  7   SYSNUM    881968 non-null  int64
#  8   MESS      881968 non-null  int64
#  9   MESSAGE   881968 non-null  object
#  10  ISACK     881968 non-null  int64
#  11  PRIORITY  881968 non-null  int64
#  12  VALUE     30428 non-null   object
# dtypes: int64(7), object(6)
# memory usage: 87.5+ MB

# %%
jornal

# %%
jornal['DTIME'] = pd.to_datetime(jornal['DTIME'])

# %%
jornal['diff'] = jornal.DTIME
jornal['diff'] = abs(jornal.DTIME.shift(periods=-1) - jornal.DTIME)

# %%
out_jo = jornal[jornal['diff']>'1 days 00:00:00']

# %%
out_jo.to_csv('out_aspt.csv')

# %%
trends[trends['Значение'].eq(trends['Значение'].shift())]
# Out:
#                                                  Описание  \
# 1       ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 451546  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 459042  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 462674  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 476387  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 481544  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 527944  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 536941  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 561504  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 570204  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 582800  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 583646  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 663815  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 666910  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# 747289  ПСП ХНПЗ. Счетчик связи. Счетчик циклов контро...
# ...
